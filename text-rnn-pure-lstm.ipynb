# %%
# 构建计算图——LSTM模型
#      embedding
#      LSTM
#      fc
#      train_op
# 训练流程代码
# 数据集封装
#      api: next_batch(batch_size)
# 词表封装
#      api: sentence2id(text_sentence): 句子转换id
# 类别封装
#      api: category2id(text_category)

import tensorflow as tf
import os
import sys
import numpy as np
import math

tf.logging.set_verbosity(tf.logging.INFO)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_default_params():
    return tf.contrib.training.HParams(
        num_embedding_size = 16,  
        num_timesteps = 50, # minibatch长度对齐
        num_lstm_nodes = [32, 32],
        num_lstm_layers = 2,
        num_fc_nodes = 32,
        batch_size = 100,
        clip_lstm_grads = 1.0, # lstm梯度
        learning_rate = 0.001,
        num_word_threshold = 10  # 词频阈值
#         num_embedding_size = 32,  
#         num_timesteps = 600, # minibatch长度对齐
#         num_lstm_nodes = [64, 64],
#         num_lstm_layers = 2,
#         num_fc_nodes = 64,
#         batch_size = 100,
#         clip_lstm_grads = 1.0, # lstm梯度
#         learning_rate = 0.001,
#         num_word_threshold = 10  # 词频阈值
    )

hps = get_default_params()

# input file
train_file = './data/cnews.train.seg.txt'
val_file = './data/cnews.val.seg.txt'
test_file = './data/cnews.test.seg.txt'
vocab_file = './data/cnews.vocab.txt'
category_file = './data/cnews.category.txt'
output_file = './data/run_text_rnn'

if not os.path.exists(output_file):
    os.mkdir(output_file)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
print(hps.num_word_threshold)
# Out:
# 10

# %%
class Vocab:
    def __init__(self, filename, num_word_threshold):
        self._word_to_id = {}
        self._unk = -1
        self._num_word_threshold = num_word_threshold
        self._read_dict(filename)
    
    def _read_dict(self, filename):
        with open(filename, 'r') as f:
            lines = f.readlines()
        for line in lines:
            word, frequency = line.strip('\r\n').split('\t')
            frequency = int(frequency)
            if frequency < self._num_word_threshold:
                continue
            idx = len(self._word_to_id) # id递增
            if word == '<UNK>':
                self._unk = idx
            self._word_to_id[word] = idx
    
    def word_to_id(self, word):
        return self._word_to_id.get(word, self._unk)
    
    @property
    def unk(self):
        return self._unk
    
    def size(self):
        return len(self._word_to_id)
        
    def sentence_to_id(self, sentence):
        word_ids = [self.word_to_id(cur_word) for cur_word in sentence.split()]
        return word_ids
    
    
class CategoryDict:
    def __init__(self, filename):
        self._category_to_id = {}
        with open(filename, 'r') as f:
            lines = f.readlines()
        for line in lines:
            category = line.strip('\r\n')
            idx = len(self._category_to_id)
            self._category_to_id[category] = idx
    
    def size(self):
        return len(self._category_to_id)
        
    def category_to_id(self, category):
        if not category in self._category_to_id:
            raise Execption("%s is not in our category list" % category_name);
        return self._category_to_id[category]
        
        
vocab = Vocab(vocab_file, hps.num_word_threshold)
vocab_size = vocab.size()
tf.logging.info('vocab_size: %d' % vocab.size())

# test_str = '的 在 了 是'
# print(vocab.sentence_to_id(test_str))

category_vocab = CategoryDict(category_file)
num_classes = category_vocab.size()
tf.logging.info('num_classes: %d' % num_classes)
test_str = '时尚'
tf.logging.info('label: %s, id: %d' % (test_str, category_vocab.category_to_id(test_str)))
# Out:
# INFO:tensorflow:vocab_size: 77323
# INFO:tensorflow:num_classes: 10
# INFO:tensorflow:label: 时尚, id: 5

# %%
class TextDataset:
    def __init__(self, filename, vocab, category_vocab, num_timesteps):
        self._vocab = vocab
        self._category_vocab = category_vocab
        self._num_timesteps = num_timesteps
        # matrix
        self._inputs = []
        # vector
        self._outputs = []
        self._indicator = 0
        self._parse_file(filename)
        
    def _parse_file(self, filename):
        tf.logging.info('Loading data from %s', filename)
        with open(filename, 'r') as f:
            lines = f.readlines()
        for line in lines:
            label, content = line.strip('\r\n').split('\t')
            id_label = self._category_vocab.category_to_id(label)
            id_words = self._vocab.sentence_to_id(content)
            id_words = id_words[0: self._num_timesteps] # 长的部分做截断
            padding_num = self._num_timesteps - len(id_words)
            id_words = id_words + [self._vocab.unk for i in range(padding_num)]
            self._inputs.append(id_words)
            self._outputs.append(id_label)
        self._inputs = np.asarray(self._inputs, dtype=np.int32)
        self._outputs = np.asarray(self._outputs, dtype=np.int32)
        self._random_shuffle()
        
    def _random_shuffle(self):
        p = np.random.permutation(len(self._inputs))
        self._inputs = self._inputs[p]
        self._outputs = self._outputs[p]
        
    def next_batch(self, batch_size):
        end_indicator = self._indicator + batch_size
        if end_indicator > len(self._inputs):
            self._random_shuffle()
            self._indicator = 0
            end_indicator = batch_size
        if end_indicator > len(self._inputs):
            raise Execption("batch_size: %d is too large" % batch_size)
        
        batch_inputs = self._inputs[self._indicator: end_indicator]
        batch_outputs = self._outputs[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_inputs, batch_outputs
    
train_dataset = TextDataset(train_file, vocab, category_vocab, hps.num_timesteps)
val_dataset = TextDataset(val_file, vocab, category_vocab, hps.num_timesteps)
test_dataset = TextDataset(test_file, vocab, category_vocab, hps.num_timesteps)

print(train_dataset.next_batch(2))
print(val_dataset.next_batch(2))
print(test_dataset.next_batch(2))
# Out:
# INFO:tensorflow:Loading data from ./data/cnews.train.seg.txt
# INFO:tensorflow:Loading data from ./data/cnews.val.seg.txt
# INFO:tensorflow:Loading data from ./data/cnews.test.seg.txt
# (array([[  287,  8097,    11,    47,  1231,   287,   232,   908,  9260,
#           321,    50,  2490,    11,    47,  1231,   287,   232,   908,
#          9260,   321,    50,   940,    11, 12337,    32,  2764,     1,
#          3085,  4831,     2,  2846, 13096,  2515,  6169,     2,  1292,
#             1,  7702,  2779,     2, 12337,   695,     6,  8396,  2143,
#             2,   785,     1,  5868,   908],
#        [   71,  1481, 39467, 10072,  6250, 10660,  2519,   250,    17,
#           250,    16,   156,   599,   456,    82,    78,   130,    23,
#           148,   269,     1,   160,  2121,  1935,   270,     1,  9027,
#         10072,  6250,   112,   113,   130,    23,    75,   319,     1,
#            22,   537,   130,    69,    23,     3,   388,    27,    94,
#            23,   941,    44,     1,    71]], dtype=int32), array([5, 8], dtype=int32))
# (array([[   15,   563, 66781,   289,    44,    14,  1383, 27041,  1693,
#            99,  2517,    17,   250,    16,  1413,     2,   246,   841,
#         12763,    22,   173,  1875,  1693,    15,   563, 66781,   289,
#            44,    14,    17,  2980, 23293,  2125, 31829,     0,     0,
#            16,     2,    99,  2517,     1,  1296,  5215,  2470,   563,
#            41,     2,    99,    92,   904],
#        [ 6117,    11,    94,    23,   174,    44, 41895,   155,  1938,
#         22406,  5717, 12316, 25913,   196,  1033,    11,     8, 20756,
#             0,  4436,     9, 30923,  5717,   196,    78,    11,  1619,
#            27,    94,    23,   174,    44,  1061,    72,   414,   196,
#          1829,    11, 41895,   155,  1938,    17,   789,  2328,  1427,
#          2119,  2385,    16,    72,   319]], dtype=int32), array([1, 3], dtype=int32))
# (array([[  246,   523,   101,   523,    72,    92, 18541,   698,   553,
#            13,    68,    41, 32256,  1839,   500,  1101,     0,  1392,
#           156,   708,  1075,  2317, 10147,  5954,  3158,    21,     1,
#          9931,  3518,   952,  7065,    30,  7226,  2160,  9930,  1839,
#             1,     4, 12940,    29,   536,     6,    68,    30,    75,
#             2,   852,     1,   780,     0],
#        [ 7220,    83,  3139, 14503, 28368,    32,  1272,   722,   239,
#          3515,   130,    23,   701,    44,   270,     1, 50142,  7220,
#          1131,  1625,    22,   113,   130,    23,   726,    44,     4,
#            82,   611,     1,  9610,   875,  1996, 55666,    10,   329,
#         11957, 38914,     0,    21,     0,    22,   411,     0,     3,
#           131,  1055,  1131,  1625,     2]], dtype=int32), array([0, 6], dtype=int32))

# %%
def create_model(hps, vocab_size, num_classes):
    num_timesteps = hps.num_timesteps
    batch_size = hps.batch_size
    
    inputs = tf.placeholder(tf.int32, (batch_size, num_timesteps))
    outputs = tf.placeholder(tf.int32, (batch_size, ))
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    global_step = tf.Variable(tf.zeros([], tf.int64), name='global_step', trainable=False)
    
    embedding_initializer = tf.random_uniform_initializer(-1.0, 1.0)
    with tf.variable_scope('embedding', initializer=embedding_initializer):
        embeddings = tf.get_variable(
            'embedding',
            [vocab_size, hps.num_embedding_size],
            tf.float32)
        # [1, 10, 7] -> [embeddings[1], embeddings[10], embeddings[7]]
        embed_inputs = tf.nn.embedding_lookup(embeddings, inputs)
        
    scale = 1.0 / math.sqrt(hps.num_embedding_size + hps.num_lstm_nodes[-1]) / 3.0
    lstm_init = tf.random_uniform_initializer(-scale, scale)
    
    def _generate_params_for_lstm_cell(x_size, h_size, bias_size):
        """generates parameters for pure lstm implementation."""
        x_w = tf.get_variable('x_weights', x_size)
        h_w = tf.get_variable('h_weights', h_size)
        b = tf.get_variable('biases', bias_size, initializer=tf.constant_initializer(0.0))
        return x_w, h_w, b
    
    with tf.variable_scope('lstm_nn', initializer = lstm_init):
        """
        cells = []
        for i in range(hps.num_lstm_layers):
            cell = tf.contrib.rnn.BasicLSTMCell(
                hps.num_lstm_nodes[i],
                state_is_tuple = True)
            cell = tf.contrib.rnn.DropoutWrapper(
                cell,
                output_keep_prob = keep_prob)
            cells.append(cell)
        cell = tf.contrib.rnn.MultiRNNCell(cells)
        
        initial_state = cell.zero_state(batch_size, tf.float32)
        # rnn_outputs: [batch_size, num_timesteps, lstm_outputs[-1]]
        rnn_outputs, _ = tf.nn.dynamic_rnn(cell, embed_inputs, initial_state = initial_state)
        last = rnn_outputs[:, -1, :]
        """
        # 输入门
        with tf.variable_scope('inputs'):
            ix, ih, ib = _generate_params_for_lstm_cell(
                x_size = [hps.num_embedding_size, hps.num_lstm_nodes[0]],
                h_size = [hps.num_lstm_nodes[0], hps.num_lstm_nodes[0]],
                bias_size = [1, hps.num_lstm_nodes[0]]
            )
            
        # 输出门
        with tf.variable_scope('outputs'):
            ox, oh, ob = _generate_params_for_lstm_cell(
                x_size = [hps.num_embedding_size, hps.num_lstm_nodes[0]],
                h_size = [hps.num_lstm_nodes[0], hps.num_lstm_nodes[0]],
                bias_size = [1, hps.num_lstm_nodes[0]]
            )
        
        # 遗忘门
        with tf.variable_scope('forget'):
            fx, fh, fb = _generate_params_for_lstm_cell(
                x_size = [hps.num_embedding_size, hps.num_lstm_nodes[0]],
                h_size = [hps.num_lstm_nodes[0], hps.num_lstm_nodes[0]],
                bias_size = [1, hps.num_lstm_nodes[0]]
            )
        
        # 中间层
        with tf.variable_scope('memory'):
            cx, ch, cb = _generate_params_for_lstm_cell(
                x_size = [hps.num_embedding_size, hps.num_lstm_nodes[0]],
                h_size = [hps.num_lstm_nodes[0], hps.num_lstm_nodes[0]],
                bias_size = [1, hps.num_lstm_nodes[0]]
            )
        state = tf.Variable(
            tf.zeros([batch_size, hps.num_lstm_nodes[0]]),
            trainable = False
        )
        h = tf.Variable(
            tf.zeros([batch_size, hps.num_lstm_nodes[0]]),
            trainable = False
        )
        for i in range(num_timesteps):
            # [batch_size, 1, embed_size]
            embed_input = embed_inputs[:, i, :]
            embed_input = tf.reshape(embed_input, [batch_size, hps.num_embedding_size])
            forget_gate = tf.sigmoid(tf.matmul(embed_input, fx) + tf.matmul(h, fh) + fb)
            input_gate = tf.sigmoid(tf.matmul(embed_input, ix) + tf.matmul(h, ih) + ib)
            output_gate = tf.sigmoid(tf.matmul(embed_input, ox) + tf.matmul(h, oh) + ob)
            mid_state = tf.tanh(tf.matmul(embed_input, cx) + tf.matmul(h, ch) + cb)
            state = mid_state * input_gate + state * forget_gate
            h = output_gate * tf.tanh(state)
        last = h
        
    fc_init = tf.uniform_unit_scaling_initializer(factor=1.0)
    with tf.variable_scope('fc', initializer=fc_init):
        fc1 = tf.layers.dense(last, hps.num_fc_nodes, activation=tf.nn.relu, name='fc1')
        fc1_dropout = tf.contrib.layers.dropout(fc1, keep_prob)
        logits = tf.layers.dense(fc1_dropout,num_classes,name='fc2')
        
    with tf.name_scope('metrics'):
        softmax_loss = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits,labels=outputs)
        loss = tf.reduce_mean(softmax_loss)
        # [0, 1, 5, 4, 2] -> argmax: 2
        y_pred = tf.argmax(tf.nn.softmax(logits), 1, output_type=tf.int32)
        correct_pred = tf.equal(outputs, y_pred)
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    with tf.name_scope('train_op'):
        tvars = tf.trainable_variables()
        for var in tvars:
            tf.logging.info('variable name: %s' %(var.name))
        grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), hps.clip_lstm_grads)
        optimizer = tf.train.AdamOptimizer(hps.learning_rate)
        train_op = optimizer.apply_gradients(zip(grads, tvars), global_step = global_step)
        
    return ((inputs, outputs, keep_prob), (loss, accuracy), (train_op, global_step))

placeholders, metrics, others = create_model(hps, vocab_size, num_classes)
inputs, outputs, keep_prob = placeholders
loss, accuracy = metrics
train_op, global_step = others
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-6-4abda70d07cb>:99: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From <ipython-input-6-4abda70d07cb>:101: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:tensorflow:variable name: embedding/embedding:0
# INFO:tensorflow:variable name: lstm_nn/inputs/x_weights:0
# INFO:tensorflow:variable name: lstm_nn/inputs/h_weights:0
# INFO:tensorflow:variable name: lstm_nn/inputs/biases:0
# INFO:tensorflow:variable name: lstm_nn/outputs/x_weights:0
# INFO:tensorflow:variable name: lstm_nn/outputs/h_weights:0
# INFO:tensorflow:variable name: lstm_nn/outputs/biases:0
# INFO:tensorflow:variable name: lstm_nn/forget/x_weights:0
# INFO:tensorflow:variable name: lstm_nn/forget/h_weights:0
# INFO:tensorflow:variable name: lstm_nn/forget/biases:0
# INFO:tensorflow:variable name: lstm_nn/memory/x_weights:0
# INFO:tensorflow:variable name: lstm_nn/memory/h_weights:0
# INFO:tensorflow:variable name: lstm_nn/memory/biases:0
# INFO:tensorflow:variable name: fc/fc1/kernel:0
# INFO:tensorflow:variable name: fc/fc1/bias:0
# INFO:tensorflow:variable name: fc/fc2/kernel:0
# INFO:tensorflow:variable name: fc/fc2/bias:0
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
init_op = tf.global_variables_initializer()
train_keep_prob_value = 0.8
test_keep_prob_value = 1.0

num_train_steps = 10000

# Train: 99.7%
# Valid: 92.7%
# Test:  93.2%
with tf.Session() as sess:
    sess.run(init_op)
    for i in range(num_train_steps):
        if i % 150 ==0:
            batch_inputs,batch_labels = test_dataset.next_batch(hps.batch_size)
        else:
            batch_inputs, batch_labels = train_dataset.next_batch(hps.batch_size)
        outputs_val = sess.run([loss, accuracy, train_op, global_step], 
        feed_dict={
            inputs: batch_inputs,
            outputs: batch_labels,
            keep_prob: train_keep_prob_value,
        })
        loss_val, accuracy_val, _, global_step_val = outputs_val
        if global_step_val % 150 == 0:
            tf.logging.info("teststep: %5d,loss: %3.3f,accuracy:%3.5f" % (global_step_val,loss_val,accuracy_val))
        if global_step_val % 20 == 0:
            tf.logging.info("trainstep: %5d,loss: %3.3f,accuracy:%3.5f" % (global_step_val,loss_val,accuracy_val))
# Out:
# INFO:tensorflow:trainstep:    20,loss: 2.302,accuracy:0.13000
# INFO:tensorflow:trainstep:    40,loss: 2.300,accuracy:0.09000
# INFO:tensorflow:trainstep:    60,loss: 2.293,accuracy:0.15000
# INFO:tensorflow:trainstep:    80,loss: 2.294,accuracy:0.13000
# INFO:tensorflow:trainstep:   100,loss: 2.294,accuracy:0.16000
# INFO:tensorflow:trainstep:   120,loss: 2.270,accuracy:0.15000
# INFO:tensorflow:trainstep:   140,loss: 2.221,accuracy:0.15000
# INFO:tensorflow:teststep:   150,loss: 2.228,accuracy:0.21000
# INFO:tensorflow:trainstep:   160,loss: 2.293,accuracy:0.16000
# INFO:tensorflow:trainstep:   180,loss: 2.197,accuracy:0.15000
# INFO:tensorflow:trainstep:   200,loss: 2.118,accuracy:0.20000
# INFO:tensorflow:trainstep:   220,loss: 2.063,accuracy:0.24000
# INFO:tensorflow:trainstep:   240,loss: 1.966,accuracy:0.26000
# INFO:tensorflow:trainstep:   260,loss: 1.826,accuracy:0.23000
# INFO:tensorflow:trainstep:   280,loss: 1.873,accuracy:0.32000
# INFO:tensorflow:teststep:   300,loss: 1.876,accuracy:0.31000
# INFO:tensorflow:trainstep:   300,loss: 1.876,accuracy:0.31000
# INFO:tensorflow:trainstep:   320,loss: 1.890,accuracy:0.21000
# INFO:tensorflow:trainstep:   340,loss: 1.771,accuracy:0.29000
# INFO:tensorflow:trainstep:   360,loss: 1.650,accuracy:0.38000
# INFO:tensorflow:trainstep:   380,loss: 1.656,accuracy:0.32000
# INFO:tensorflow:trainstep:   400,loss: 1.794,accuracy:0.24000
# INFO:tensorflow:trainstep:   420,loss: 1.798,accuracy:0.26000
# INFO:tensorflow:trainstep:   440,loss: 1.576,accuracy:0.37000
# INFO:tensorflow:teststep:   450,loss: 1.547,accuracy:0.38000
# INFO:tensorflow:trainstep:   460,loss: 1.589,accuracy:0.42000
# INFO:tensorflow:trainstep:   480,loss: 1.638,accuracy:0.31000
# INFO:tensorflow:trainstep:   500,loss: 1.716,accuracy:0.30000
# INFO:tensorflow:trainstep:   520,loss: 1.689,accuracy:0.26000
# INFO:tensorflow:trainstep:   540,loss: 1.485,accuracy:0.35000
# INFO:tensorflow:trainstep:   560,loss: 1.469,accuracy:0.36000
# INFO:tensorflow:trainstep:   580,loss: 1.476,accuracy:0.41000
# INFO:tensorflow:teststep:   600,loss: 1.513,accuracy:0.43000
# INFO:tensorflow:trainstep:   600,loss: 1.513,accuracy:0.43000
# INFO:tensorflow:trainstep:   620,loss: 1.466,accuracy:0.39000
# INFO:tensorflow:trainstep:   640,loss: 1.494,accuracy:0.46000
# INFO:tensorflow:trainstep:   660,loss: 1.448,accuracy:0.44000
# INFO:tensorflow:trainstep:   680,loss: 1.297,accuracy:0.50000
# INFO:tensorflow:trainstep:   700,loss: 1.325,accuracy:0.41000
# INFO:tensorflow:trainstep:   720,loss: 1.261,accuracy:0.46000
# INFO:tensorflow:trainstep:   740,loss: 1.309,accuracy:0.50000
# INFO:tensorflow:teststep:   750,loss: 1.433,accuracy:0.48000
# INFO:tensorflow:trainstep:   760,loss: 1.204,accuracy:0.51000
# INFO:tensorflow:trainstep:   780,loss: 1.587,accuracy:0.36000
# INFO:tensorflow:trainstep:   800,loss: 1.255,accuracy:0.54000
# INFO:tensorflow:trainstep:   820,loss: 1.223,accuracy:0.51000
# INFO:tensorflow:trainstep:   840,loss: 1.493,accuracy:0.45000
# INFO:tensorflow:trainstep:   860,loss: 1.333,accuracy:0.50000
# INFO:tensorflow:trainstep:   880,loss: 1.115,accuracy:0.49000
# INFO:tensorflow:teststep:   900,loss: 1.267,accuracy:0.54000
# INFO:tensorflow:trainstep:   900,loss: 1.267,accuracy:0.54000
# INFO:tensorflow:trainstep:   920,loss: 1.203,accuracy:0.59000
# INFO:tensorflow:trainstep:   940,loss: 1.114,accuracy:0.59000
# INFO:tensorflow:trainstep:   960,loss: 1.090,accuracy:0.64000
# INFO:tensorflow:trainstep:   980,loss: 1.142,accuracy:0.54000
# INFO:tensorflow:trainstep:  1000,loss: 1.155,accuracy:0.55000
# INFO:tensorflow:trainstep:  1020,loss: 1.090,accuracy:0.61000
# INFO:tensorflow:trainstep:  1040,loss: 1.041,accuracy:0.66000
# INFO:tensorflow:teststep:  1050,loss: 0.896,accuracy:0.67000
# INFO:tensorflow:trainstep:  1060,loss: 1.136,accuracy:0.60000
# INFO:tensorflow:trainstep:  1080,loss: 1.021,accuracy:0.63000
# INFO:tensorflow:trainstep:  1100,loss: 1.156,accuracy:0.61000
# INFO:tensorflow:trainstep:  1120,loss: 1.122,accuracy:0.64000
# INFO:tensorflow:trainstep:  1140,loss: 0.954,accuracy:0.66000
# INFO:tensorflow:trainstep:  1160,loss: 0.842,accuracy:0.74000
# INFO:tensorflow:trainstep:  1180,loss: 1.032,accuracy:0.67000
# INFO:tensorflow:teststep:  1200,loss: 0.864,accuracy:0.72000
# INFO:tensorflow:trainstep:  1200,loss: 0.864,accuracy:0.72000
# INFO:tensorflow:trainstep:  1220,loss: 1.109,accuracy:0.58000
# INFO:tensorflow:trainstep:  1240,loss: 1.084,accuracy:0.63000
# INFO:tensorflow:trainstep:  1260,loss: 0.893,accuracy:0.68000
# INFO:tensorflow:trainstep:  1280,loss: 1.023,accuracy:0.61000
# INFO:tensorflow:trainstep:  1300,loss: 0.915,accuracy:0.62000
# INFO:tensorflow:trainstep:  1320,loss: 0.948,accuracy:0.69000
# INFO:tensorflow:trainstep:  1340,loss: 0.861,accuracy:0.68000
# INFO:tensorflow:teststep:  1350,loss: 0.651,accuracy:0.78000
# INFO:tensorflow:trainstep:  1360,loss: 0.925,accuracy:0.69000
# INFO:tensorflow:trainstep:  1380,loss: 0.801,accuracy:0.69000
# INFO:tensorflow:trainstep:  1400,loss: 0.976,accuracy:0.68000
# INFO:tensorflow:trainstep:  1420,loss: 1.066,accuracy:0.64000
# INFO:tensorflow:trainstep:  1440,loss: 0.996,accuracy:0.65000
# INFO:tensorflow:trainstep:  1460,loss: 0.804,accuracy:0.70000
# INFO:tensorflow:trainstep:  1480,loss: 0.859,accuracy:0.65000
# INFO:tensorflow:teststep:  1500,loss: 0.817,accuracy:0.72000
# INFO:tensorflow:trainstep:  1500,loss: 0.817,accuracy:0.72000
# INFO:tensorflow:trainstep:  1520,loss: 0.829,accuracy:0.70000
# INFO:tensorflow:trainstep:  1540,loss: 0.766,accuracy:0.79000
# INFO:tensorflow:trainstep:  1560,loss: 0.675,accuracy:0.77000
# INFO:tensorflow:trainstep:  1580,loss: 0.840,accuracy:0.70000
# INFO:tensorflow:trainstep:  1600,loss: 0.835,accuracy:0.78000
# INFO:tensorflow:trainstep:  1620,loss: 0.633,accuracy:0.80000
# INFO:tensorflow:trainstep:  1640,loss: 0.746,accuracy:0.73000
# INFO:tensorflow:teststep:  1650,loss: 0.710,accuracy:0.80000
# INFO:tensorflow:trainstep:  1660,loss: 0.721,accuracy:0.79000
# INFO:tensorflow:trainstep:  1680,loss: 0.765,accuracy:0.73000
# INFO:tensorflow:trainstep:  1700,loss: 0.635,accuracy:0.82000
# INFO:tensorflow:trainstep:  1720,loss: 0.777,accuracy:0.75000
# INFO:tensorflow:trainstep:  1740,loss: 0.657,accuracy:0.79000
# INFO:tensorflow:trainstep:  1760,loss: 0.698,accuracy:0.72000
# INFO:tensorflow:trainstep:  1780,loss: 0.741,accuracy:0.76000
# INFO:tensorflow:teststep:  1800,loss: 0.623,accuracy:0.84000
# INFO:tensorflow:trainstep:  1800,loss: 0.623,accuracy:0.84000
# INFO:tensorflow:trainstep:  1820,loss: 0.758,accuracy:0.79000
# INFO:tensorflow:trainstep:  1840,loss: 0.728,accuracy:0.78000
# INFO:tensorflow:trainstep:  1860,loss: 0.808,accuracy:0.71000
# INFO:tensorflow:trainstep:  1880,loss: 0.772,accuracy:0.76000
# INFO:tensorflow:trainstep:  1900,loss: 0.714,accuracy:0.75000
# INFO:tensorflow:trainstep:  1920,loss: 0.723,accuracy:0.73000
# INFO:tensorflow:trainstep:  1940,loss: 0.910,accuracy:0.74000
# INFO:tensorflow:teststep:  1950,loss: 0.829,accuracy:0.77000
# INFO:tensorflow:trainstep:  1960,loss: 0.610,accuracy:0.80000
# INFO:tensorflow:trainstep:  1980,loss: 0.823,accuracy:0.75000
# INFO:tensorflow:trainstep:  2000,loss: 0.934,accuracy:0.76000
# INFO:tensorflow:trainstep:  2020,loss: 0.586,accuracy:0.82000
# INFO:tensorflow:trainstep:  2040,loss: 0.413,accuracy:0.87000
# INFO:tensorflow:trainstep:  2060,loss: 0.371,accuracy:0.90000
# INFO:tensorflow:trainstep:  2080,loss: 0.664,accuracy:0.79000
# INFO:tensorflow:teststep:  2100,loss: 0.519,accuracy:0.85000
# INFO:tensorflow:trainstep:  2100,loss: 0.519,accuracy:0.85000
# INFO:tensorflow:trainstep:  2120,loss: 0.625,accuracy:0.82000
# INFO:tensorflow:trainstep:  2140,loss: 0.901,accuracy:0.79000
# INFO:tensorflow:trainstep:  2160,loss: 0.509,accuracy:0.83000
# INFO:tensorflow:trainstep:  2180,loss: 0.501,accuracy:0.85000
# INFO:tensorflow:trainstep:  2200,loss: 0.611,accuracy:0.82000
# INFO:tensorflow:trainstep:  2220,loss: 0.499,accuracy:0.87000
# INFO:tensorflow:trainstep:  2240,loss: 0.420,accuracy:0.87000
# INFO:tensorflow:teststep:  2250,loss: 0.525,accuracy:0.84000
# INFO:tensorflow:trainstep:  2260,loss: 0.461,accuracy:0.85000
# INFO:tensorflow:trainstep:  2280,loss: 0.711,accuracy:0.75000
# INFO:tensorflow:trainstep:  2300,loss: 0.580,accuracy:0.79000
# INFO:tensorflow:trainstep:  2320,loss: 0.753,accuracy:0.76000
# INFO:tensorflow:trainstep:  2340,loss: 0.718,accuracy:0.80000
# INFO:tensorflow:trainstep:  2360,loss: 0.593,accuracy:0.80000
# INFO:tensorflow:trainstep:  2380,loss: 0.593,accuracy:0.78000
# INFO:tensorflow:teststep:  2400,loss: 0.479,accuracy:0.83000
# INFO:tensorflow:trainstep:  2400,loss: 0.479,accuracy:0.83000
# INFO:tensorflow:trainstep:  2420,loss: 0.780,accuracy:0.71000
# INFO:tensorflow:trainstep:  2440,loss: 0.375,accuracy:0.91000
# INFO:tensorflow:trainstep:  2460,loss: 0.436,accuracy:0.88000
# INFO:tensorflow:trainstep:  2480,loss: 0.562,accuracy:0.85000
# INFO:tensorflow:trainstep:  2500,loss: 0.814,accuracy:0.75000
# INFO:tensorflow:trainstep:  2520,loss: 0.426,accuracy:0.88000
# INFO:tensorflow:trainstep:  2540,loss: 0.511,accuracy:0.85000
# INFO:tensorflow:teststep:  2550,loss: 0.540,accuracy:0.87000
# INFO:tensorflow:trainstep:  2560,loss: 0.540,accuracy:0.84000
# INFO:tensorflow:trainstep:  2580,loss: 0.445,accuracy:0.85000
# INFO:tensorflow:trainstep:  2600,loss: 0.571,accuracy:0.85000
# INFO:tensorflow:trainstep:  2620,loss: 0.530,accuracy:0.86000
# INFO:tensorflow:trainstep:  2640,loss: 0.698,accuracy:0.83000
# INFO:tensorflow:trainstep:  2660,loss: 0.310,accuracy:0.90000
# INFO:tensorflow:trainstep:  2680,loss: 0.617,accuracy:0.80000
# INFO:tensorflow:teststep:  2700,loss: 0.497,accuracy:0.87000
# INFO:tensorflow:trainstep:  2700,loss: 0.497,accuracy:0.87000
# INFO:tensorflow:trainstep:  2720,loss: 0.466,accuracy:0.92000
# INFO:tensorflow:trainstep:  2740,loss: 0.492,accuracy:0.84000
# INFO:tensorflow:trainstep:  2760,loss: 0.315,accuracy:0.90000
# INFO:tensorflow:trainstep:  2780,loss: 0.382,accuracy:0.91000
# INFO:tensorflow:trainstep:  2800,loss: 0.418,accuracy:0.87000
# INFO:tensorflow:trainstep:  2820,loss: 0.306,accuracy:0.93000
# INFO:tensorflow:trainstep:  2840,loss: 0.493,accuracy:0.84000
# INFO:tensorflow:teststep:  2850,loss: 0.406,accuracy:0.91000
# INFO:tensorflow:trainstep:  2860,loss: 0.475,accuracy:0.88000
# INFO:tensorflow:trainstep:  2880,loss: 0.449,accuracy:0.87000
# INFO:tensorflow:trainstep:  2900,loss: 0.519,accuracy:0.85000
# INFO:tensorflow:trainstep:  2920,loss: 0.487,accuracy:0.86000
# INFO:tensorflow:trainstep:  2940,loss: 0.438,accuracy:0.88000
# INFO:tensorflow:trainstep:  2960,loss: 0.428,accuracy:0.86000
# INFO:tensorflow:trainstep:  2980,loss: 0.314,accuracy:0.91000
# INFO:tensorflow:teststep:  3000,loss: 0.558,accuracy:0.86000
# INFO:tensorflow:trainstep:  3000,loss: 0.558,accuracy:0.86000
# INFO:tensorflow:trainstep:  3020,loss: 0.430,accuracy:0.90000
# INFO:tensorflow:trainstep:  3040,loss: 0.441,accuracy:0.87000
# INFO:tensorflow:trainstep:  3060,loss: 0.302,accuracy:0.92000
# INFO:tensorflow:trainstep:  3080,loss: 0.425,accuracy:0.88000
# INFO:tensorflow:trainstep:  3100,loss: 0.212,accuracy:0.96000
# INFO:tensorflow:trainstep:  3120,loss: 0.304,accuracy:0.91000
# INFO:tensorflow:trainstep:  3140,loss: 0.459,accuracy:0.91000
# INFO:tensorflow:teststep:  3150,loss: 0.445,accuracy:0.86000
# INFO:tensorflow:trainstep:  3160,loss: 0.352,accuracy:0.90000
# INFO:tensorflow:trainstep:  3180,loss: 0.307,accuracy:0.90000
# INFO:tensorflow:trainstep:  3200,loss: 0.289,accuracy:0.91000
# INFO:tensorflow:trainstep:  3220,loss: 0.419,accuracy:0.88000
# INFO:tensorflow:trainstep:  3240,loss: 0.373,accuracy:0.85000
# INFO:tensorflow:trainstep:  3260,loss: 0.279,accuracy:0.92000
# INFO:tensorflow:trainstep:  3280,loss: 0.400,accuracy:0.89000
# INFO:tensorflow:teststep:  3300,loss: 0.278,accuracy:0.92000
# INFO:tensorflow:trainstep:  3300,loss: 0.278,accuracy:0.92000
# INFO:tensorflow:trainstep:  3320,loss: 0.331,accuracy:0.90000
# INFO:tensorflow:trainstep:  3340,loss: 0.345,accuracy:0.91000
# INFO:tensorflow:trainstep:  3360,loss: 0.285,accuracy:0.95000
# INFO:tensorflow:trainstep:  3380,loss: 0.331,accuracy:0.91000
# INFO:tensorflow:trainstep:  3400,loss: 0.464,accuracy:0.88000
# INFO:tensorflow:trainstep:  3420,loss: 0.488,accuracy:0.91000
# INFO:tensorflow:trainstep:  3440,loss: 0.441,accuracy:0.91000
# INFO:tensorflow:teststep:  3450,loss: 0.383,accuracy:0.91000
# INFO:tensorflow:trainstep:  3460,loss: 0.367,accuracy:0.92000
# INFO:tensorflow:trainstep:  3480,loss: 0.395,accuracy:0.91000
# INFO:tensorflow:trainstep:  3500,loss: 0.386,accuracy:0.91000
# INFO:tensorflow:trainstep:  3520,loss: 0.477,accuracy:0.88000
# INFO:tensorflow:trainstep:  3540,loss: 0.208,accuracy:0.95000
# INFO:tensorflow:trainstep:  3560,loss: 0.294,accuracy:0.90000
# INFO:tensorflow:trainstep:  3580,loss: 0.291,accuracy:0.93000
# INFO:tensorflow:teststep:  3600,loss: 0.143,accuracy:0.97000
# INFO:tensorflow:trainstep:  3600,loss: 0.143,accuracy:0.97000
# INFO:tensorflow:trainstep:  3620,loss: 0.275,accuracy:0.92000
# INFO:tensorflow:trainstep:  3640,loss: 0.322,accuracy:0.89000
# INFO:tensorflow:trainstep:  3660,loss: 0.424,accuracy:0.94000
# INFO:tensorflow:trainstep:  3680,loss: 0.231,accuracy:0.91000
# INFO:tensorflow:trainstep:  3700,loss: 0.210,accuracy:0.94000
# INFO:tensorflow:trainstep:  3720,loss: 0.172,accuracy:0.95000
# INFO:tensorflow:trainstep:  3740,loss: 0.139,accuracy:0.96000
# INFO:tensorflow:teststep:  3750,loss: 0.450,accuracy:0.89000
# INFO:tensorflow:trainstep:  3760,loss: 0.241,accuracy:0.91000
# INFO:tensorflow:trainstep:  3780,loss: 0.159,accuracy:0.98000
# INFO:tensorflow:trainstep:  3800,loss: 0.400,accuracy:0.88000
# INFO:tensorflow:trainstep:  3820,loss: 0.264,accuracy:0.90000
# INFO:tensorflow:trainstep:  3840,loss: 0.329,accuracy:0.93000
# INFO:tensorflow:trainstep:  3860,loss: 0.246,accuracy:0.91000
# INFO:tensorflow:trainstep:  3880,loss: 0.367,accuracy:0.89000
# INFO:tensorflow:teststep:  3900,loss: 0.288,accuracy:0.92000
# INFO:tensorflow:trainstep:  3900,loss: 0.288,accuracy:0.92000
# INFO:tensorflow:trainstep:  3920,loss: 0.268,accuracy:0.91000
# INFO:tensorflow:trainstep:  3940,loss: 0.228,accuracy:0.94000
# INFO:tensorflow:trainstep:  3960,loss: 0.226,accuracy:0.95000
# INFO:tensorflow:trainstep:  3980,loss: 0.430,accuracy:0.90000
# INFO:tensorflow:trainstep:  4000,loss: 0.233,accuracy:0.94000
# INFO:tensorflow:trainstep:  4020,loss: 0.506,accuracy:0.88000
# INFO:tensorflow:trainstep:  4040,loss: 0.360,accuracy:0.93000
# INFO:tensorflow:teststep:  4050,loss: 0.216,accuracy:0.95000
# INFO:tensorflow:trainstep:  4060,loss: 0.125,accuracy:0.98000
# INFO:tensorflow:trainstep:  4080,loss: 0.225,accuracy:0.94000
# INFO:tensorflow:trainstep:  4100,loss: 0.091,accuracy:0.97000
# INFO:tensorflow:trainstep:  4120,loss: 0.230,accuracy:0.93000
# INFO:tensorflow:trainstep:  4140,loss: 0.256,accuracy:0.94000
# INFO:tensorflow:trainstep:  4160,loss: 0.393,accuracy:0.89000
# INFO:tensorflow:trainstep:  4180,loss: 0.227,accuracy:0.91000
# INFO:tensorflow:teststep:  4200,loss: 0.164,accuracy:0.97000
# INFO:tensorflow:trainstep:  4200,loss: 0.164,accuracy:0.97000
# INFO:tensorflow:trainstep:  4220,loss: 0.368,accuracy:0.88000
# INFO:tensorflow:trainstep:  4240,loss: 0.216,accuracy:0.94000
# INFO:tensorflow:trainstep:  4260,loss: 0.490,accuracy:0.89000
# INFO:tensorflow:trainstep:  4280,loss: 0.181,accuracy:0.96000
# INFO:tensorflow:trainstep:  4300,loss: 0.114,accuracy:0.98000
# INFO:tensorflow:trainstep:  4320,loss: 0.330,accuracy:0.94000
# INFO:tensorflow:trainstep:  4340,loss: 0.217,accuracy:0.93000
# INFO:tensorflow:teststep:  4350,loss: 0.254,accuracy:0.90000
# INFO:tensorflow:trainstep:  4360,loss: 0.205,accuracy:0.94000
# INFO:tensorflow:trainstep:  4380,loss: 0.125,accuracy:0.97000
# INFO:tensorflow:trainstep:  4400,loss: 0.268,accuracy:0.92000
# INFO:tensorflow:trainstep:  4420,loss: 0.321,accuracy:0.91000
# INFO:tensorflow:trainstep:  4440,loss: 0.156,accuracy:0.95000
# INFO:tensorflow:trainstep:  4460,loss: 0.204,accuracy:0.94000
# INFO:tensorflow:trainstep:  4480,loss: 0.280,accuracy:0.94000
# INFO:tensorflow:teststep:  4500,loss: 0.215,accuracy:0.95000
# INFO:tensorflow:trainstep:  4500,loss: 0.215,accuracy:0.95000
# INFO:tensorflow:trainstep:  4520,loss: 0.204,accuracy:0.95000
# INFO:tensorflow:trainstep:  4540,loss: 0.082,accuracy:0.98000
# INFO:tensorflow:trainstep:  4560,loss: 0.222,accuracy:0.94000
# INFO:tensorflow:trainstep:  4580,loss: 0.341,accuracy:0.92000
# INFO:tensorflow:trainstep:  4600,loss: 0.199,accuracy:0.96000
# INFO:tensorflow:trainstep:  4620,loss: 0.152,accuracy:0.97000
# INFO:tensorflow:trainstep:  4640,loss: 0.062,accuracy:0.99000
# INFO:tensorflow:teststep:  4650,loss: 0.042,accuracy:0.99000
# INFO:tensorflow:trainstep:  4660,loss: 0.141,accuracy:0.97000
# INFO:tensorflow:trainstep:  4680,loss: 0.126,accuracy:0.97000
# INFO:tensorflow:trainstep:  4700,loss: 0.074,accuracy:0.98000
# INFO:tensorflow:trainstep:  4720,loss: 0.069,accuracy:0.99000
# INFO:tensorflow:trainstep:  4740,loss: 0.118,accuracy:0.96000
# INFO:tensorflow:trainstep:  4760,loss: 0.277,accuracy:0.93000
# INFO:tensorflow:trainstep:  4780,loss: 0.223,accuracy:0.96000
# INFO:tensorflow:teststep:  4800,loss: 0.143,accuracy:0.97000
# INFO:tensorflow:trainstep:  4800,loss: 0.143,accuracy:0.97000
# INFO:tensorflow:trainstep:  4820,loss: 0.128,accuracy:0.96000
# INFO:tensorflow:trainstep:  4840,loss: 0.079,accuracy:0.97000
# INFO:tensorflow:trainstep:  4860,loss: 0.322,accuracy:0.93000
# INFO:tensorflow:trainstep:  4880,loss: 0.243,accuracy:0.91000
# INFO:tensorflow:trainstep:  4900,loss: 0.199,accuracy:0.97000
# INFO:tensorflow:trainstep:  4920,loss: 0.189,accuracy:0.95000
# INFO:tensorflow:trainstep:  4940,loss: 0.391,accuracy:0.91000
# INFO:tensorflow:teststep:  4950,loss: 0.323,accuracy:0.91000
# INFO:tensorflow:trainstep:  4960,loss: 0.337,accuracy:0.93000
# INFO:tensorflow:trainstep:  4980,loss: 0.220,accuracy:0.94000
# INFO:tensorflow:trainstep:  5000,loss: 0.277,accuracy:0.94000
# INFO:tensorflow:trainstep:  5020,loss: 0.320,accuracy:0.94000
# INFO:tensorflow:trainstep:  5040,loss: 0.222,accuracy:0.94000
# INFO:tensorflow:trainstep:  5060,loss: 0.252,accuracy:0.97000
# INFO:tensorflow:trainstep:  5080,loss: 0.147,accuracy:0.97000
# INFO:tensorflow:teststep:  5100,loss: 0.123,accuracy:0.96000
# INFO:tensorflow:trainstep:  5100,loss: 0.123,accuracy:0.96000
# INFO:tensorflow:trainstep:  5120,loss: 0.219,accuracy:0.96000
# INFO:tensorflow:trainstep:  5140,loss: 0.298,accuracy:0.92000
# INFO:tensorflow:trainstep:  5160,loss: 0.169,accuracy:0.94000
# INFO:tensorflow:trainstep:  5180,loss: 0.244,accuracy:0.95000
# INFO:tensorflow:trainstep:  5200,loss: 0.201,accuracy:0.97000
# INFO:tensorflow:trainstep:  5220,loss: 0.157,accuracy:0.98000
# INFO:tensorflow:trainstep:  5240,loss: 0.123,accuracy:0.97000
# INFO:tensorflow:teststep:  5250,loss: 0.129,accuracy:0.96000
# INFO:tensorflow:trainstep:  5260,loss: 0.151,accuracy:0.96000
# INFO:tensorflow:trainstep:  5280,loss: 0.146,accuracy:0.97000
# INFO:tensorflow:trainstep:  5300,loss: 0.069,accuracy:0.98000
# INFO:tensorflow:trainstep:  5320,loss: 0.207,accuracy:0.95000
# INFO:tensorflow:trainstep:  5340,loss: 0.270,accuracy:0.93000
# INFO:tensorflow:trainstep:  5360,loss: 0.226,accuracy:0.94000
# INFO:tensorflow:trainstep:  5380,loss: 0.224,accuracy:0.93000
# INFO:tensorflow:teststep:  5400,loss: 0.145,accuracy:0.97000
# INFO:tensorflow:trainstep:  5400,loss: 0.145,accuracy:0.97000
# INFO:tensorflow:trainstep:  5420,loss: 0.159,accuracy:0.97000
# INFO:tensorflow:trainstep:  5440,loss: 0.059,accuracy:0.99000
# INFO:tensorflow:trainstep:  5460,loss: 0.106,accuracy:0.99000
# INFO:tensorflow:trainstep:  5480,loss: 0.198,accuracy:0.95000
# INFO:tensorflow:trainstep:  5500,loss: 0.145,accuracy:0.94000
# INFO:tensorflow:trainstep:  5520,loss: 0.294,accuracy:0.96000
# INFO:tensorflow:trainstep:  5540,loss: 0.057,accuracy:0.98000
# INFO:tensorflow:teststep:  5550,loss: 0.056,accuracy:0.98000
# INFO:tensorflow:trainstep:  5560,loss: 0.108,accuracy:0.93000
# INFO:tensorflow:trainstep:  5580,loss: 0.050,accuracy:0.99000
# INFO:tensorflow:trainstep:  5600,loss: 0.186,accuracy:0.96000
# INFO:tensorflow:trainstep:  5620,loss: 0.127,accuracy:0.97000
# INFO:tensorflow:trainstep:  5640,loss: 0.053,accuracy:1.00000
# INFO:tensorflow:trainstep:  5660,loss: 0.027,accuracy:1.00000
# INFO:tensorflow:trainstep:  5680,loss: 0.109,accuracy:0.97000
# INFO:tensorflow:teststep:  5700,loss: 0.101,accuracy:0.97000
# INFO:tensorflow:trainstep:  5700,loss: 0.101,accuracy:0.97000
# INFO:tensorflow:trainstep:  5720,loss: 0.213,accuracy:0.96000
# INFO:tensorflow:trainstep:  5740,loss: 0.168,accuracy:0.96000
# INFO:tensorflow:trainstep:  5760,loss: 0.066,accuracy:0.98000
# INFO:tensorflow:trainstep:  5780,loss: 0.072,accuracy:0.99000
# INFO:tensorflow:trainstep:  5800,loss: 0.117,accuracy:0.97000
# INFO:tensorflow:trainstep:  5820,loss: 0.202,accuracy:0.95000
# INFO:tensorflow:trainstep:  5840,loss: 0.093,accuracy:0.97000
# INFO:tensorflow:teststep:  5850,loss: 0.018,accuracy:1.00000
# INFO:tensorflow:trainstep:  5860,loss: 0.137,accuracy:0.95000
# INFO:tensorflow:trainstep:  5880,loss: 0.132,accuracy:0.99000
# INFO:tensorflow:trainstep:  5900,loss: 0.068,accuracy:0.99000
# INFO:tensorflow:trainstep:  5920,loss: 0.131,accuracy:0.95000
# INFO:tensorflow:trainstep:  5940,loss: 0.057,accuracy:0.99000
# INFO:tensorflow:trainstep:  5960,loss: 0.083,accuracy:0.99000
# INFO:tensorflow:trainstep:  5980,loss: 0.174,accuracy:0.95000
# INFO:tensorflow:teststep:  6000,loss: 0.069,accuracy:0.99000
# INFO:tensorflow:trainstep:  6000,loss: 0.069,accuracy:0.99000
# INFO:tensorflow:trainstep:  6020,loss: 0.132,accuracy:0.95000
# INFO:tensorflow:trainstep:  6040,loss: 0.231,accuracy:0.95000
# INFO:tensorflow:trainstep:  6060,loss: 0.158,accuracy:0.97000
# INFO:tensorflow:trainstep:  6080,loss: 0.107,accuracy:0.97000
# INFO:tensorflow:trainstep:  6100,loss: 0.165,accuracy:0.97000
# INFO:tensorflow:trainstep:  6120,loss: 0.038,accuracy:0.99000
# INFO:tensorflow:trainstep:  6140,loss: 0.035,accuracy:0.99000
# INFO:tensorflow:teststep:  6150,loss: 0.147,accuracy:0.96000
# INFO:tensorflow:trainstep:  6160,loss: 0.098,accuracy:0.97000
# INFO:tensorflow:trainstep:  6180,loss: 0.025,accuracy:1.00000
# INFO:tensorflow:trainstep:  6200,loss: 0.039,accuracy:0.99000
# INFO:tensorflow:trainstep:  6220,loss: 0.046,accuracy:0.99000
# INFO:tensorflow:trainstep:  6240,loss: 0.034,accuracy:1.00000
# INFO:tensorflow:trainstep:  6260,loss: 0.082,accuracy:0.97000
# INFO:tensorflow:trainstep:  6280,loss: 0.122,accuracy:0.97000
# INFO:tensorflow:teststep:  6300,loss: 0.125,accuracy:0.96000
# INFO:tensorflow:trainstep:  6300,loss: 0.125,accuracy:0.96000
# INFO:tensorflow:trainstep:  6320,loss: 0.159,accuracy:0.96000
# INFO:tensorflow:trainstep:  6340,loss: 0.043,accuracy:0.99000
# INFO:tensorflow:trainstep:  6360,loss: 0.127,accuracy:0.97000
# INFO:tensorflow:trainstep:  6380,loss: 0.046,accuracy:0.99000
# INFO:tensorflow:trainstep:  6400,loss: 0.065,accuracy:0.98000
# INFO:tensorflow:trainstep:  6420,loss: 0.116,accuracy:0.98000
# INFO:tensorflow:trainstep:  6440,loss: 0.052,accuracy:0.99000
# INFO:tensorflow:teststep:  6450,loss: 0.121,accuracy:0.96000
# INFO:tensorflow:trainstep:  6460,loss: 0.233,accuracy:0.96000
# INFO:tensorflow:trainstep:  6480,loss: 0.093,accuracy:0.98000
# INFO:tensorflow:trainstep:  6500,loss: 0.017,accuracy:1.00000
# INFO:tensorflow:trainstep:  6520,loss: 0.033,accuracy:0.99000
# INFO:tensorflow:trainstep:  6540,loss: 0.046,accuracy:0.98000
# INFO:tensorflow:trainstep:  6560,loss: 0.060,accuracy:0.99000
# INFO:tensorflow:trainstep:  6580,loss: 0.075,accuracy:0.98000
# INFO:tensorflow:teststep:  6600,loss: 0.268,accuracy:0.97000
# INFO:tensorflow:trainstep:  6600,loss: 0.268,accuracy:0.97000
# INFO:tensorflow:trainstep:  6620,loss: 0.104,accuracy:0.99000
# INFO:tensorflow:trainstep:  6640,loss: 0.032,accuracy:0.99000
# INFO:tensorflow:trainstep:  6660,loss: 0.259,accuracy:0.97000
# INFO:tensorflow:trainstep:  6680,loss: 0.166,accuracy:0.95000
# INFO:tensorflow:trainstep:  6700,loss: 0.022,accuracy:1.00000
# INFO:tensorflow:trainstep:  6720,loss: 0.116,accuracy:0.97000
# INFO:tensorflow:trainstep:  6740,loss: 0.084,accuracy:0.98000
# INFO:tensorflow:teststep:  6750,loss: 0.121,accuracy:0.96000
# INFO:tensorflow:trainstep:  6760,loss: 0.085,accuracy:0.97000
# INFO:tensorflow:trainstep:  6780,loss: 0.086,accuracy:0.98000
# INFO:tensorflow:trainstep:  6800,loss: 0.157,accuracy:0.96000
# INFO:tensorflow:trainstep:  6820,loss: 0.098,accuracy:0.98000
# INFO:tensorflow:trainstep:  6840,loss: 0.109,accuracy:0.97000
# INFO:tensorflow:trainstep:  6860,loss: 0.159,accuracy:0.96000
# INFO:tensorflow:trainstep:  6880,loss: 0.088,accuracy:0.98000
# INFO:tensorflow:teststep:  6900,loss: 0.050,accuracy:0.98000
# INFO:tensorflow:trainstep:  6900,loss: 0.050,accuracy:0.98000
# INFO:tensorflow:trainstep:  6920,loss: 0.129,accuracy:0.98000
# INFO:tensorflow:trainstep:  6940,loss: 0.147,accuracy:0.97000
# INFO:tensorflow:trainstep:  6960,loss: 0.126,accuracy:0.98000
# INFO:tensorflow:trainstep:  6980,loss: 0.020,accuracy:1.00000
# INFO:tensorflow:trainstep:  7000,loss: 0.036,accuracy:0.99000
# INFO:tensorflow:trainstep:  7020,loss: 0.146,accuracy:0.97000
# INFO:tensorflow:trainstep:  7040,loss: 0.080,accuracy:0.98000
# INFO:tensorflow:teststep:  7050,loss: 0.122,accuracy:0.96000
# INFO:tensorflow:trainstep:  7060,loss: 0.092,accuracy:0.98000
# INFO:tensorflow:trainstep:  7080,loss: 0.041,accuracy:0.99000
# INFO:tensorflow:trainstep:  7100,loss: 0.109,accuracy:0.97000
# INFO:tensorflow:trainstep:  7120,loss: 0.296,accuracy:0.96000
# INFO:tensorflow:trainstep:  7140,loss: 0.073,accuracy:0.99000
# INFO:tensorflow:trainstep:  7160,loss: 0.067,accuracy:0.99000
# INFO:tensorflow:trainstep:  7180,loss: 0.028,accuracy:0.98000
# INFO:tensorflow:teststep:  7200,loss: 0.088,accuracy:0.98000
# INFO:tensorflow:trainstep:  7200,loss: 0.088,accuracy:0.98000
# INFO:tensorflow:trainstep:  7220,loss: 0.064,accuracy:0.99000
# INFO:tensorflow:trainstep:  7240,loss: 0.026,accuracy:0.99000
# INFO:tensorflow:trainstep:  7260,loss: 0.052,accuracy:0.98000
# INFO:tensorflow:trainstep:  7280,loss: 0.052,accuracy:0.98000
# INFO:tensorflow:trainstep:  7300,loss: 0.083,accuracy:0.98000
# INFO:tensorflow:trainstep:  7320,loss: 0.140,accuracy:0.96000
# INFO:tensorflow:trainstep:  7340,loss: 0.090,accuracy:0.97000
# INFO:tensorflow:teststep:  7350,loss: 0.032,accuracy:0.98000
# INFO:tensorflow:trainstep:  7360,loss: 0.189,accuracy:0.96000
# INFO:tensorflow:trainstep:  7380,loss: 0.011,accuracy:1.00000
# INFO:tensorflow:trainstep:  7400,loss: 0.064,accuracy:0.97000
# INFO:tensorflow:trainstep:  7420,loss: 0.116,accuracy:0.99000
# INFO:tensorflow:trainstep:  7440,loss: 0.063,accuracy:0.99000
# INFO:tensorflow:trainstep:  7460,loss: 0.146,accuracy:0.98000
# INFO:tensorflow:trainstep:  7480,loss: 0.026,accuracy:1.00000
# INFO:tensorflow:teststep:  7500,loss: 0.214,accuracy:0.95000
# INFO:tensorflow:trainstep:  7500,loss: 0.214,accuracy:0.95000
# INFO:tensorflow:trainstep:  7520,loss: 0.036,accuracy:0.99000
# INFO:tensorflow:trainstep:  7540,loss: 0.036,accuracy:1.00000
# INFO:tensorflow:trainstep:  7560,loss: 0.009,accuracy:1.00000
# INFO:tensorflow:trainstep:  7580,loss: 0.021,accuracy:1.00000
# INFO:tensorflow:trainstep:  7600,loss: 0.052,accuracy:0.98000
# INFO:tensorflow:trainstep:  7620,loss: 0.090,accuracy:0.98000
# INFO:tensorflow:trainstep:  7640,loss: 0.035,accuracy:0.98000
# INFO:tensorflow:teststep:  7650,loss: 0.067,accuracy:0.99000
# INFO:tensorflow:trainstep:  7660,loss: 0.023,accuracy:1.00000
# INFO:tensorflow:trainstep:  7680,loss: 0.062,accuracy:0.99000
# INFO:tensorflow:trainstep:  7700,loss: 0.045,accuracy:0.99000
# INFO:tensorflow:trainstep:  7720,loss: 0.180,accuracy:0.96000
# INFO:tensorflow:trainstep:  7740,loss: 0.054,accuracy:0.99000
# INFO:tensorflow:trainstep:  7760,loss: 0.013,accuracy:1.00000
# INFO:tensorflow:trainstep:  7780,loss: 0.014,accuracy:1.00000
# INFO:tensorflow:teststep:  7800,loss: 0.074,accuracy:0.98000
# INFO:tensorflow:trainstep:  7800,loss: 0.074,accuracy:0.98000
# INFO:tensorflow:trainstep:  7820,loss: 0.047,accuracy:0.99000
# INFO:tensorflow:trainstep:  7840,loss: 0.016,accuracy:1.00000
# INFO:tensorflow:trainstep:  7860,loss: 0.030,accuracy:0.99000
# INFO:tensorflow:trainstep:  7880,loss: 0.051,accuracy:0.98000
# INFO:tensorflow:trainstep:  7900,loss: 0.099,accuracy:0.98000
# INFO:tensorflow:trainstep:  7920,loss: 0.048,accuracy:0.98000
# INFO:tensorflow:trainstep:  7940,loss: 0.038,accuracy:0.99000
# INFO:tensorflow:teststep:  7950,loss: 0.017,accuracy:0.99000
# INFO:tensorflow:trainstep:  7960,loss: 0.127,accuracy:0.98000
# INFO:tensorflow:trainstep:  7980,loss: 0.082,accuracy:0.97000
# INFO:tensorflow:trainstep:  8000,loss: 0.079,accuracy:0.98000
# INFO:tensorflow:trainstep:  8020,loss: 0.042,accuracy:0.99000
# INFO:tensorflow:trainstep:  8040,loss: 0.119,accuracy:0.97000
# INFO:tensorflow:trainstep:  8060,loss: 0.025,accuracy:0.99000
# INFO:tensorflow:trainstep:  8080,loss: 0.023,accuracy:1.00000
# INFO:tensorflow:teststep:  8100,loss: 0.041,accuracy:0.99000
# INFO:tensorflow:trainstep:  8100,loss: 0.041,accuracy:0.99000
# INFO:tensorflow:trainstep:  8120,loss: 0.073,accuracy:0.98000
# INFO:tensorflow:trainstep:  8140,loss: 0.005,accuracy:1.00000
# INFO:tensorflow:trainstep:  8160,loss: 0.061,accuracy:0.98000
# INFO:tensorflow:trainstep:  8180,loss: 0.119,accuracy:0.98000
# INFO:tensorflow:trainstep:  8200,loss: 0.172,accuracy:0.97000
# INFO:tensorflow:trainstep:  8220,loss: 0.100,accuracy:0.99000
# INFO:tensorflow:trainstep:  8240,loss: 0.180,accuracy:0.97000
# INFO:tensorflow:teststep:  8250,loss: 0.069,accuracy:0.99000
# INFO:tensorflow:trainstep:  8260,loss: 0.081,accuracy:0.99000
# INFO:tensorflow:trainstep:  8280,loss: 0.087,accuracy:0.98000
# INFO:tensorflow:trainstep:  8300,loss: 0.007,accuracy:1.00000
# INFO:tensorflow:trainstep:  8320,loss: 0.020,accuracy:1.00000
# INFO:tensorflow:trainstep:  8340,loss: 0.029,accuracy:0.99000
# INFO:tensorflow:trainstep:  8360,loss: 0.027,accuracy:0.99000
# INFO:tensorflow:trainstep:  8380,loss: 0.062,accuracy:0.98000
# INFO:tensorflow:teststep:  8400,loss: 0.086,accuracy:0.98000
# INFO:tensorflow:trainstep:  8400,loss: 0.086,accuracy:0.98000
# INFO:tensorflow:trainstep:  8420,loss: 0.030,accuracy:0.99000
# INFO:tensorflow:trainstep:  8440,loss: 0.022,accuracy:1.00000
# INFO:tensorflow:trainstep:  8460,loss: 0.280,accuracy:0.97000
# INFO:tensorflow:trainstep:  8480,loss: 0.025,accuracy:1.00000
# INFO:tensorflow:trainstep:  8500,loss: 0.065,accuracy:0.99000
# INFO:tensorflow:trainstep:  8520,loss: 0.049,accuracy:0.99000
# INFO:tensorflow:trainstep:  8540,loss: 0.082,accuracy:0.96000
# INFO:tensorflow:teststep:  8550,loss: 0.046,accuracy:0.98000
# INFO:tensorflow:trainstep:  8560,loss: 0.030,accuracy:0.99000
# INFO:tensorflow:trainstep:  8580,loss: 0.017,accuracy:1.00000
# INFO:tensorflow:trainstep:  8600,loss: 0.020,accuracy:0.99000
# INFO:tensorflow:trainstep:  8620,loss: 0.095,accuracy:0.99000
# INFO:tensorflow:trainstep:  8640,loss: 0.020,accuracy:0.99000
# INFO:tensorflow:trainstep:  8660,loss: 0.064,accuracy:0.99000
# INFO:tensorflow:trainstep:  8680,loss: 0.096,accuracy:0.98000
# INFO:tensorflow:teststep:  8700,loss: 0.110,accuracy:0.97000
# INFO:tensorflow:trainstep:  8700,loss: 0.110,accuracy:0.97000
# INFO:tensorflow:trainstep:  8720,loss: 0.101,accuracy:0.98000
# INFO:tensorflow:trainstep:  8740,loss: 0.014,accuracy:1.00000
# INFO:tensorflow:trainstep:  8760,loss: 0.031,accuracy:0.99000
# INFO:tensorflow:trainstep:  8780,loss: 0.003,accuracy:1.00000
# INFO:tensorflow:trainstep:  8800,loss: 0.060,accuracy:0.99000
# INFO:tensorflow:trainstep:  8820,loss: 0.006,accuracy:1.00000
# INFO:tensorflow:trainstep:  8840,loss: 0.011,accuracy:1.00000
# INFO:tensorflow:teststep:  8850,loss: 0.016,accuracy:1.00000
# INFO:tensorflow:trainstep:  8860,loss: 0.017,accuracy:1.00000
# INFO:tensorflow:trainstep:  8880,loss: 0.014,accuracy:1.00000
# INFO:tensorflow:trainstep:  8900,loss: 0.019,accuracy:1.00000
# INFO:tensorflow:trainstep:  8920,loss: 0.025,accuracy:0.99000
# INFO:tensorflow:trainstep:  8940,loss: 0.008,accuracy:1.00000
# INFO:tensorflow:trainstep:  8960,loss: 0.073,accuracy:0.99000
# INFO:tensorflow:trainstep:  8980,loss: 0.012,accuracy:1.00000
# INFO:tensorflow:teststep:  9000,loss: 0.105,accuracy:0.97000
# INFO:tensorflow:trainstep:  9000,loss: 0.105,accuracy:0.97000
# INFO:tensorflow:trainstep:  9020,loss: 0.012,accuracy:1.00000
# INFO:tensorflow:trainstep:  9040,loss: 0.005,accuracy:1.00000
# INFO:tensorflow:trainstep:  9060,loss: 0.006,accuracy:1.00000
# INFO:tensorflow:trainstep:  9080,loss: 0.009,accuracy:1.00000
# INFO:tensorflow:trainstep:  9100,loss: 0.012,accuracy:1.00000
# INFO:tensorflow:trainstep:  9120,loss: 0.004,accuracy:1.00000
# INFO:tensorflow:trainstep:  9140,loss: 0.111,accuracy:0.99000
# INFO:tensorflow:teststep:  9150,loss: 0.120,accuracy:0.98000
# INFO:tensorflow:trainstep:  9160,loss: 0.302,accuracy:0.96000
# INFO:tensorflow:trainstep:  9180,loss: 0.021,accuracy:0.99000
# INFO:tensorflow:trainstep:  9200,loss: 0.108,accuracy:0.98000
# INFO:tensorflow:trainstep:  9220,loss: 0.006,accuracy:1.00000
# INFO:tensorflow:trainstep:  9240,loss: 0.034,accuracy:0.99000
# INFO:tensorflow:trainstep:  9260,loss: 0.051,accuracy:0.99000
# INFO:tensorflow:trainstep:  9280,loss: 0.035,accuracy:0.99000
# INFO:tensorflow:teststep:  9300,loss: 0.083,accuracy:0.97000
# INFO:tensorflow:trainstep:  9300,loss: 0.083,accuracy:0.97000
# INFO:tensorflow:trainstep:  9320,loss: 0.051,accuracy:0.99000
# INFO:tensorflow:trainstep:  9340,loss: 0.018,accuracy:1.00000
# INFO:tensorflow:trainstep:  9360,loss: 0.036,accuracy:0.99000
# INFO:tensorflow:trainstep:  9380,loss: 0.014,accuracy:1.00000
# INFO:tensorflow:trainstep:  9400,loss: 0.102,accuracy:0.98000
# INFO:tensorflow:trainstep:  9420,loss: 0.012,accuracy:1.00000
# INFO:tensorflow:trainstep:  9440,loss: 0.125,accuracy:0.96000
# INFO:tensorflow:teststep:  9450,loss: 0.025,accuracy:0.99000
# INFO:tensorflow:trainstep:  9460,loss: 0.070,accuracy:0.99000
# INFO:tensorflow:trainstep:  9480,loss: 0.008,accuracy:1.00000
# INFO:tensorflow:trainstep:  9500,loss: 0.077,accuracy:0.99000
# INFO:tensorflow:trainstep:  9520,loss: 0.018,accuracy:0.99000
# INFO:tensorflow:trainstep:  9540,loss: 0.004,accuracy:1.00000
# INFO:tensorflow:trainstep:  9560,loss: 0.031,accuracy:0.98000
# INFO:tensorflow:trainstep:  9580,loss: 0.007,accuracy:1.00000
# INFO:tensorflow:teststep:  9600,loss: 0.037,accuracy:0.98000
# INFO:tensorflow:trainstep:  9600,loss: 0.037,accuracy:0.98000
# INFO:tensorflow:trainstep:  9620,loss: 0.106,accuracy:0.97000
# INFO:tensorflow:trainstep:  9640,loss: 0.131,accuracy:0.98000
# INFO:tensorflow:trainstep:  9660,loss: 0.009,accuracy:1.00000
# INFO:tensorflow:trainstep:  9680,loss: 0.004,accuracy:1.00000
# INFO:tensorflow:trainstep:  9700,loss: 0.007,accuracy:1.00000
# INFO:tensorflow:trainstep:  9720,loss: 0.006,accuracy:1.00000
# INFO:tensorflow:trainstep:  9740,loss: 0.010,accuracy:1.00000
# INFO:tensorflow:teststep:  9750,loss: 0.011,accuracy:1.00000
# INFO:tensorflow:trainstep:  9760,loss: 0.026,accuracy:0.99000
# INFO:tensorflow:trainstep:  9780,loss: 0.005,accuracy:1.00000
# INFO:tensorflow:trainstep:  9800,loss: 0.072,accuracy:0.98000
# INFO:tensorflow:trainstep:  9820,loss: 0.062,accuracy:0.99000
# INFO:tensorflow:trainstep:  9840,loss: 0.014,accuracy:1.00000
# INFO:tensorflow:trainstep:  9860,loss: 0.005,accuracy:1.00000
# INFO:tensorflow:trainstep:  9880,loss: 0.009,accuracy:1.00000
# INFO:tensorflow:teststep:  9900,loss: 0.011,accuracy:1.00000
# INFO:tensorflow:trainstep:  9900,loss: 0.011,accuracy:1.00000
# INFO:tensorflow:trainstep:  9920,loss: 0.008,accuracy:1.00000
# INFO:tensorflow:trainstep:  9940,loss: 0.005,accuracy:1.00000
# INFO:tensorflow:trainstep:  9960,loss: 0.004,accuracy:1.00000
# INFO:tensorflow:trainstep:  9980,loss: 0.003,accuracy:1.00000
# INFO:tensorflow:trainstep: 10000,loss: 0.041,accuracy:0.99000
